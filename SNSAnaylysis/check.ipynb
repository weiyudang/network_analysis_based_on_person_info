# %%
sql_call='''select custorm_id,name,number,call_time,type,time from crawler.app_call_record_hive  where cast(name as float) is NULL and length(number)>6   and cast(time as float)<25200 
and cast(time as float)>=0 and   name is not NULL   and custorm_id=9111411 order by call_time'''
app_call_record=sqlContext.sql(sql_call)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7fb13a0e756> in <module>()
#       1 sql_call='''select custorm_id,name,number,call_time,type,time from crawler.app_call_record_hive  where cast(name as float) is NULL and length(number)>6   and cast(time as float)<25200
#       2 and cast(time as float)>=0 and   name is not NULL   and custorm_id=9111411 order by call_time'''
# ----> 3 app_call_record=sqlContext.sql(sql_call)
#
# NameError: name 'sqlContext' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib  inline 
from pylab import mpl
import matplotlib
mpl.rcParams['font.sans-serif'] = ['simhei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
myfont = matplotlib.font_manager.FontProperties(fname='../fonts/simhei.ttf')  
mpl.rcParams['axes.unicode_minus'] = False 
import tushare as ts
# data=ts.get_hist_data('600817')

# %%
plt.plot(data.open,data.close)
plt.title(u'股票',fontproperties=myfont)

# %%
data=data.drop_duplicates(['number','call_time']) ## 548436550

# %%
data.saveAsParquetFile('./MSN/app_call_record_hive_0301')
# Out:
# 548436550

# %% [markdown]
# gdl_cust_user_info.toPandas().to_csv('MSN/gdl_cut_ino_0301.csv')

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.total_bill/2.0
# Out:
# 0       8.495
# 1       5.170
# 2      10.505
# 3      11.840
# 4      12.295
# 5      12.645
# 6       4.385
# 7      13.440
# 8       7.520
# 9       7.390
# 10      5.135
# 11     17.630
# 12      7.710
# 13      9.215
# 14      7.415
# 15     10.790
# 16      5.165
# 17      8.145
# 18      8.485
# 19     10.325
# 20      8.960
# 21     10.145
# 22      7.885
# 23     19.710
# 24      9.910
# 25      8.905
# 26      6.685
# 27      6.345
# 28     10.850
# 29      9.825
#         ...
# 214    14.085
# 215     6.450
# 216    14.075
# 217     5.795
# 218     3.870
# 219    15.070
# 220     6.080
# 221     6.710
# 222     4.290
# 223     7.990
# 224     6.710
# 225     8.135
# 226     5.045
# 227    10.225
# 228     6.640
# 229    11.060
# 230    12.005
# 231     7.845
# 232     5.805
# 233     5.385
# 234     7.765
# 235     5.035
# 236     6.300
# 237    16.415
# 238    17.915
# 239    14.515
# 240    13.590
# 241    11.335
# 242     8.910
# 243     9.390
# ...

# %%
# %time mobi_call_records_partitions=pd.read_csv("data/mobi/mobi_call_record_0919_1013_1_2_3_4.csv",index_col=0)
# Out:
# <string>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 25.6 s, sys: 2.85 s, total: 28.4 s
# Wall time: 28.4 s

# %%
mobi_call_records_partitions.head(3)
# Out:
#    custorm_id   login_name  type_contact  num_contact         time_contact  \
# 0     4174468  13589028200             2           49  2016-09-21 15:17:52
# 1     4174468  13589028200             2           31  2016-09-21 14:36:51
# 2     4174468  13589028200             2          116  2016-09-21 14:20:04
#
#   phone_contact  type_call
# 0   1.83512e+10          1
# 1   1.83512e+10          1
# 2   1.83512e+10          1

# %%
mobi_call_records_partitions['phone_contact'][0]
# Out:
# 0    1.83512e+10
# 0    1.82815e+10
# 0    1.52821e+10
# 0    1.39897e+10
# 0    1.58816e+10
# 0            663
# 0    1.89935e+10
# 0    1.51823e+10
# 0    1.35292e+10
# 0    1.51002e+10
# 0    1.35985e+10
# 0    1.58886e+10
# 0    1.53795e+10
# 0    1.37328e+10
# 0    17783630308
# 0         669743
# 0    15854535087
# 0    17878396517
# 0    13587965980
# 0    18115556665
# 0    4.00789e+09
# 0    1.50522e+10
# 0    1.30707e+10
# 0    1.52295e+10
# 0    1.30707e+10
# 0    1.82768e+10
# 0    1.87679e+10
# 0    2.15194e+09
# 0     1.3657e+10
# 0    1.80553e+10
#         ...
# 0     7525907551
# 0    13131030035
# 0    13928923561
# 0    13988975519
# 0    13118017630
# 0    15387671620
# 0    18685592507
# 0    13125851289
# 0    18693536728
# 0     3918615550
# 0    14763589223
# 0    57582500226
# 0    15036321235
# 0    18390960566
# 0    15013510589
# 0    13093863121
# 0            661
# 0    15214540716
# 0    15060325982
# 0    18961931259
# 0    15091128768
# ...
